# %%
from devCellPy.importing_modules import *
from devCellPy.layer import Layer

layer = pd.read_pickle('/Users/sidraxu/Desktop/SeanWuLab/devCellPy/devCellPy/Cardiac Atlas Trained Models/Root/Cardiomyocytes/E105/E105VentricularCM/E105VentricularCM_object.pkl')

import pickle
with open('/Users/sidraxu/Desktop/SeanWuLab/devCellPy/devCellPy/Cardiac Atlas Trained Models/Root/Cardiomyocytes/E105/E105VentricularCM/E105VentricularCM_object_new.pkl', 'wb') as f:
    pickle.dump(layer, f)
# Out:
# [14:48:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.

# %%
layer = pd.read_pickle('/Users/sidraxu/Desktop/SeanWuLab/devCellPy/devCellPy/Cardiac Atlas Trained Models/Root/Cardiomyocytes/E825/E825_object.pkl')
layer.name = 'Cardiomyocytes'
layer.level = 1
layer.labeldict[2] = 'Ventricular CM'

print(layer)
import pickle
with open('/Users/sidraxu/Desktop/SeanWuLab/devCellPy/devCellPy/Cardiac Atlas Trained Models/Root/Cardiomyocytes/E825/E825_object_new.pkl', 'wb') as f:
    pickle.dump(layer, f)
# Out:
# [18:47:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# Object: E8.25_object.pkl
# Layer: Cardiomyocytes
# Level: 1
# Label Dictionary: {0: 'Atrial CM', 1: 'AVC CM', 2: 'Ventricular CM'}
# Finetuning Log: E8.25_finetuning.csv
# XGB Model: Cardiomyocytes_xgbmodel.sav
# 10-Fold Cross Validation Metrics: E8.25_cvmetrics.txt
# Final Metrics: E8.25_finalmetrics.txt
# Predictions (no rejection): E8.25_trainingpredictions_reject0.csv
# Predictions (None rejection cutoff): E8.25_trainingpredictions_reject0.5.csv
# ...

# %%
layer = pd.read_pickle('/Users/sidraxu/Desktop/SeanWuLab/devCellPy/devCellPy/Cardiac Atlas Trained Models/Root/Cardiomyocytes/E135/E135VentricularCM/E135VentricularCM_object.pkl')
layer.name = 'Ventricular CM'
layer.level = 2

import pickle
with open('/Users/sidraxu/Desktop/SeanWuLab/devCellPy/devCellPy/Cardiac Atlas Trained Models/Root/Cardiomyocytes/E135/E135VentricularCM/E135VentricularCM_object_new.pkl', 'wb') as f:
    pickle.dump(layer, f)
